# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Muat model YOLO bawaan
model = YOLO('runs/detect/runs/detect/train/ppe_model/weights/best.pt')

# Contoh pengujian (uncomment dan ganti dengan path gambar Anda jika ingin mencoba)
results = model('apd-1/test/images/coba.jpg')
res = results[0].plot()
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# image 1/1 d:\project_gadiza\DeteksiAPD\apd-1\test\images\coba.jpg: 640x640 2 Helmets, 2 Vests, 211.2ms
# Speed: 29.7ms preprocess, 211.2ms inference, 10.3ms postprocess per image at shape (1, 3, 640, 640)
