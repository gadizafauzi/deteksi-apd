# %% [markdown]
# # Training YOLO11 dengan Dataset Roboflow

# %%
# !pip install roboflow ultralytics --user
# Out:
# ...
#   Using cached roboflow-1.3.10-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pi_heif-1.4.0-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached roboflow-1.3.10-py3-none-any.whl (250 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...

# %%
from roboflow import Roboflow
from ultralytics import YOLO

rf = Roboflow(api_key="QKUBNaENfqEq1VrYZSdE")
project = rf.workspace("gadizas-workspace-rlkcf").project("apd-zzz88-gro91")
version = project.version(1)
dataset = version.download("yolov8")

print("\nDataset berhasil diunduh di:", dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to APD-1 in yolov8:: 100%|██████████| 70/70 [00:00<00:00, 1151.02it/s]
# Dataset berhasil diunduh di: d:\project_gadiza\DeteksiAPD\APD-1

# %%
# 2. Mulai proses Training
# Muat model dasar bawaan (versi nano agar cepat)
model = YOLO('yolo11n.pt')

# Latih model dengan dataset yang baru saja diunduh
results = model.train(
    data=f"{dataset.location}/data.yaml", 
    epochs=50,      # Jumlah iterasi pelatihan (sesuaikan)
    imgsz=640,      # Ukuran gambar
    batch=8,       # Ukuran batch (turunkan ke 8 jika memori GPU tidak kuat)
    project="runs/detect/train",
    name="ppe_model" # Hasil akhir akan ada di runs/detect/train/ppe_model/weights/best.pt
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.67 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.66  Python-3.10.11 torch-2.12.0+cpu CPU (11th Gen Intel Core(TM) i3-1115G4 3.00GHz)
# ...
